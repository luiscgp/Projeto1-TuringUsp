# %% [markdown]
# ## Importação de Pacotes e Dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("df_athlete_events.csv")
noc_regions = pd.read_csv("nocRegions.csv") # Dataframe com relação de NOC pra Country

# %% [markdown]
# ## Informações Iniciais e Limpeza dos dados

# %%
df.head(10)
# Out:
#    Athlete_ID                      Name   Sex   Age  Height Weight  \
# 0           4      Edgar Lindenau Aabye     M  34.0     NaN    NaN
# 1           6           Per Knut Aaland     M  31.0   188.0   75.0
# 2          15      Arvo Ossian Aaltonen     M  30.0     NaN    NaN
# 3          15      Arvo Ossian Aaltonen     M  30.0     NaN    NaN
# 4          16  Juhamatti Tapio Aaltonen     M  28.0   184.0   85.0
# 5          17   Paavo Johannes Aaltonen     M  28.0   175.0   64.0
# 6          17   Paavo Johannes Aaltonen     M  28.0   175.0   64.0
# 7          17   Paavo Johannes Aaltonen  MALE  28.0   175.0   64.0
# 8          17   Paavo Johannes Aaltonen     M  28.0   175.0   64.0
# 9          17   Paavo Johannes Aaltonen     M  32.0   175.0   64.0
#
#              Team  NOC        Games  Year  Season         City  \
# 0  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 1   United States  USA  1992 Winter  1992  Winter  Albertville
# 2         Finland  FIN  1920 Summer  1920  Summer    Antwerpen
# 3         Finland  FIN  1920 Summer  1920  Summer    Antwerpen
# 4         Finland  FIN  2014 Winter  2014  Winter        Sochi
# 5         Finland  FIN  1948 Summer  1948  Summer       London
# 6         Finland  FIN  1948 Summer  1948  Summer       London
# 7         Finland  FIN  1948 Summer  1948  Summer       London
# 8         Finland  FIN  1948 Summer  1948  Summer       London
# 9         Finland  FIN  1952 Summer  1952  Summer     Helsinki
#
#                   Sport                                              Event  \
# 0            Tug-Of-War                        Tug-Of-War Men's Tug-Of-War
# 1  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 2              Swimming             Swimming Men's 200 metres Breaststroke
# 3              Swimming             Swimming Men's 400 metres Breaststroke
# 4            Ice Hockey                        Ice Hockey Men's Ice Hockey
# 5            Gymnastics             Gymnastics Men's Individual All-Around
# 6            Gymnastics                   Gymnastics Men's Team All-Around
# 7            Gymnastics                       Gymnastics Men's Horse Vault
# 8            Gymnastics                   Gymnastics Men's Pommelled Horse
# 9            Gymnastics                   Gymnastics Men's Team All-Around
#
#     Medal
# 0    Gold
# 1     NaN
# 2  Bronze
# 3  Bronze
# 4  Bronze
# 5  Bronze
# 6    Gold
# 7    Gold
# 8    Gold
# 9  Bronze

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45567 entries, 0 to 45566
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Athlete_ID  45567 non-null  int64
#  1   Name        45567 non-null  object
#  2   Sex         45567 non-null  object
#  3   Age         44594 non-null  float64
#  4   Height      35547 non-null  float64
#  5   Weight      34926 non-null  object
#  6   Team        45567 non-null  object
#  7   NOC         45567 non-null  object
#  8   Games       45567 non-null  object
#  9   Year        45567 non-null  int64
#  10  Season      45567 non-null  object
#  11  City        45567 non-null  object
#  12  Sport       45567 non-null  object
#  13  Event       45567 non-null  object
#  14  Medal       39804 non-null  object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 5.2+ MB

# %% [markdown]
#  Temos 14 colunas, 4 numéricas e outras 10 como object. Entretanto, weight em teoria precisa ser uma coluna numérica. Além disso, percebe-se que as colunas Age, Height, Weight e Medal possuem valores faltantes.

# %%
df.isnull().sum().where(df.isnull().sum() > 0).dropna()
# Out:
# Age         973.0
# Height    10020.0
# Weight    10641.0
# Medal      5763.0
# dtype: float64

# %% [markdown]
# ### Valores Numéricos

# %% [markdown]
# <p>Aqui observamos que existem colunas com valores NaNs, que precisamos tratar adequadamente. Em relação a Medal, interpretaremos como sem medalha. Sobre Age, Height e Weight trocaremos seus valores faltantes pela média dos valores coerentes da coluna </p>

# %%
df["Medal"].replace({None: "No Medal"}, inplace = True)

# %%
df.head()
# Out:
#    Athlete_ID                      Name Sex   Age  Height Weight  \
# 0           4      Edgar Lindenau Aabye   M  34.0     NaN    NaN
# 1           6           Per Knut Aaland   M  31.0   188.0   75.0
# 2          15      Arvo Ossian Aaltonen   M  30.0     NaN    NaN
# 3          15      Arvo Ossian Aaltonen   M  30.0     NaN    NaN
# 4          16  Juhamatti Tapio Aaltonen   M  28.0   184.0   85.0
#
#              Team  NOC        Games  Year  Season         City  \
# 0  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 1   United States  USA  1992 Winter  1992  Winter  Albertville
# 2         Finland  FIN  1920 Summer  1920  Summer    Antwerpen
# 3         Finland  FIN  1920 Summer  1920  Summer    Antwerpen
# 4         Finland  FIN  2014 Winter  2014  Winter        Sochi
#
#                   Sport                                              Event  \
# 0            Tug-Of-War                        Tug-Of-War Men's Tug-Of-War
# 1  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 2              Swimming             Swimming Men's 200 metres Breaststroke
# 3              Swimming             Swimming Men's 400 metres Breaststroke
# 4            Ice Hockey                        Ice Hockey Men's Ice Hockey
#
#       Medal
# 0      Gold
# 1  No Medal
# 2    Bronze
# 3    Bronze
# 4    Bronze

# %% [markdown]
# Antes de analisarmos os valores faltantes de Age, Weight e Height, trocaremos o tipo da coluna Weight.

# %%
df.Weight = pd.to_numeric(df.Weight, errors='coerce')

# %%
df.dtypes
# Out:
# Athlete_ID      int64
# Name           object
# Sex            object
# Age           float64
# Height        float64
# Weight        float64
# Team           object
# NOC            object
# Games          object
# Year            int64
# Season         object
# City           object
# Sport          object
# Event          object
# Medal          object
# dtype: object

# %% [markdown]
# Agora sim, podemos avaliar os valores numéricos faltantes e discrepantes

# %%
df.describe()
# Out:
#           Athlete_ID           Age        Height        Weight          Year
# count   45567.000000  44594.000000  3.554700e+04  34426.000000  45567.000000
# mean    69129.286282     25.851348  9.729939e+02     73.482450   1972.391094
# std     38866.485546      5.966053  3.446781e+04     14.977912     94.200678
# min         4.000000     10.000000  1.320000e+02     28.000000  -2992.000000
# 25%     36105.500000     22.000000  1.700000e+02     63.000000   1952.000000
# 50%     68634.000000     25.000000  1.780000e+02     72.000000   1984.000000
# 75%    103181.000000     29.000000  1.850000e+02     82.000000   2002.000000
# max    135563.000000     73.000000  1.976779e+06    214.000000   2016.000000

# %% [markdown]
# <p>   Primeiramente para a coluna Age, que representa a Idade dos esportistas. Os valores minimos e máximos são coerentes com dados históricos pesquisados, portanto o unico problema na análise seria a ausencia de alguns dados.</p>
# <p>   Para a coluna Height, além dos dados faltantes, o valor máximo é incoerente com a realidade humana.</p>
# <p>   Para a coluna Weight, os dados parecem coerentes, o problema também são os os dados faltantes.</p>
# <p>   Para a coluna Year, possuem valores incoerentes para o numero minimo.</p>

# %%
alturasincoerentes = df[df["Height"] > 272].Height.values

# %%
AlturaMedia = df[~df['Height'].isin(df[df["Height"] > 272].Height)].Height.mean()

# %%
df['Height'] = df['Height'].map(lambda x: AlturaMedia if (x in alturasincoerentes) else x)

# %%
df.describe()
# Out:
#           Athlete_ID           Age        Height        Weight          Year
# count   45567.000000  44594.000000  35547.000000  34426.000000  45567.000000
# mean    69129.286282     25.851348    177.218534     73.482450   1972.391094
# std     38866.485546      5.966053     10.862522     14.977912     94.200678
# min         4.000000     10.000000    132.000000     28.000000  -2992.000000
# 25%     36105.500000     22.000000    170.000000     63.000000   1952.000000
# 50%     68634.000000     25.000000    178.000000     72.000000   1984.000000
# 75%    103181.000000     29.000000    184.000000     82.000000   2002.000000
# max    135563.000000     73.000000    223.000000    214.000000   2016.000000

# %% [markdown]
#    Agora os problemas são apenas os valores faltantes, que iremos substituir pelos valores médios.

# %%
df['Height'].fillna(round(df.Height.mean(),2), inplace = True)

# %%
df['Weight'].fillna(round(df.Weight.mean(),2), inplace = True)

# %%
df['Age'].fillna(df.Age.mean().round(), inplace = True)

# %%
df.isnull().sum().where(df.isnull().sum() > 0).dropna()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Para a coluna Year, usaremos os quatro primeiros caracteres da coluna Games, que indica o ano de acontecimento dos jogos.

# %%
print(sorted(df["Games"].unique()))
# Out:
# ['1896 Summer', '1900 Summer', '1904 Summer', '1906 Summer', '1908 Summer', '1912 Summer', '1920 Summer', '1924 Summer', '1924 Winter', '1928 Summer', '1928 Winter', '1932 Summer', '1932 Winter', '1936 Summer', '1936 Winter', '1948 Summer', '1948 Winter', '1952 Summer', '1952 Winter', '1956 Summer', '1956 Winter', '1960 Summer', '1960 Winter', '1964 Summer', '1964 Winter', '1968 Summer', '1968 Winter', '1972 Summer', '1972 Winter', '1976 Summer', '1976 Winter', '1980 Summer', '1980 Winter', '1984 Summer', '1984 Winter', '1988 Summer', '1988 Winter', '1992 Summer', '1992 Winter', '1994 Winter', '1996 Summer', '1998 Winter', '2000 Summer', '2002 Winter', '2004 Summer', '2006 Winter', '2008 Summer', '2010 Winter', '2012 Summer', '2014 Winter', '2016 Summer']

# %%
df["Year"] = df["Games"].str[:4]
df["Year"] = pd.to_numeric(df["Year"])

# %%
df["Year"].unique()
# Out:
# array([1900, 1992, 1920, 2014, 1948, 1952, 1994, 2002, 2006, 2008, 1988,
#        1996, 1960, 1912, 1956, 2016, 2000, 2012, 2004, 1980, 1984, 1936,
#        1906, 1964, 1972, 1924, 1904, 1932, 1928, 1998, 1968, 1976, 2010,
#        1908, 1896], dtype=int64)

# %% [markdown]
# Agora que substituimos todos os valores faltantes podemos análisar se os valores catégóricos são coerentes.

# %% [markdown]
# ### Valores Categóricos

# %%
df.columns
# Out:
# Index(['Athlete_ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC',
#        'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.Sex.unique()
# Out:
# array(['M', 'MALE', 'FEMALE', 'F', 'Vic vai te dar um socao',
#        'P&D >> Comunidade'], dtype=object)

# %% [markdown]
# Aqui vemos que possuem valores incoerentes na coluna Sex. Substituiremos MALE por M, FEMALE por F e analisaremos as outras duas para ver como substituiremos adequadamente.

# %%
df.loc[df['Sex'].isin(['Vic vai te dar um socao',
       'P&D >> Comunidade'])]
# Out:
#        Athlete_ID                              Name                      Sex  \
# 21             30                  Pepijn Aardewijn  Vic vai te dar um socao
# 131           562                 Pawe Abratkiewicz  Vic vai te dar um socao
# 227           963              Derrick Ralph Adkins  Vic vai te dar um socao
# 355          1435              Janne Petteri Ahonen  Vic vai te dar um socao
# 365          1467  Mara Magdalena Aicega Amicarelli        P&D >> Comunidade
# ...           ...                               ...                      ...
# 44982      133933            Javier Adelmar Zanetti  Vic vai te dar um socao
# 45021      134077     Nataliya Borisovna Zasulskaya        P&D >> Comunidade
# 45103      134294          Martina Zellner (-Seidl)        P&D >> Comunidade
# 45187      134531                        Zhang Ping        P&D >> Comunidade
# 45280      134800                         Zhou Lulu        P&D >> Comunidade
#
#         Age  Height  Weight           Team  NOC        Games  Year  Season  \
# 21     26.0   189.0    72.0    Netherlands  NED  1996 Summer  1996  Summer
# 131    27.0   183.0    84.0         Poland  POL  1998 Winter  1998  Winter
# 227    26.0   188.0    80.0  United States  USA  1996 Summer  1996  Summer
# 355    28.0   184.0    66.0        Finland  FIN  2006 Winter  2006  Winter
# 365    34.0   165.0    60.0      Argentina  ARG  2008 Summer  2008  Summer
# ...     ...     ...     ...            ...  ...          ...   ...     ...
# 44982  22.0   178.0    73.0      Argentina  ARG  1996 Summer  1996  Summer
# 45021  23.0   190.0    95.0   Unified Team  EUN  1992 Summer  1992  Summer
# 45103  23.0   169.0    62.0        Germany  GER  1998 Winter  1998  Winter
# 45187  22.0   187.0    73.0          China  CHN  2004 Summer  2004  Summer
# 45280  24.0   175.0   133.0          China  CHN  2012 Summer  2012  Summer
#
#             City          Sport                                      Event  \
# 21       Atlanta         Rowing     Rowing Men's Lightweight Double Sculls
# 131       Nagano  Speed Skating             Speed Skating Men's 500 metres
# 227      Atlanta      Athletics         Athletics Men's 400 metres Hurdles
# 355       Torino    Ski Jumping         Ski Jumping Men's Large Hill, Team
# 365      Beijing         Hockey                      Hockey Women's Hockey
# ...          ...            ...                                        ...
# 44982    Atlanta       Football                    Football Men's Football
# 45021  Barcelona     Basketball              Basketball Women's Basketball
# 45103     Nagano       Biathlon  Biathlon Women's 4 x 7.5 kilometres Relay
# 45187     Athina     Volleyball              Volleyball Women's Volleyball
# 45280     London  Weightlifting    Weightlifting Women's Super-Heavyweight
#
#           Medal
# 21       Silver
# 131    No Medal
# 227        Gold
# 355      Silver
# 365      Bronze
# ...         ...
# 44982    Silver
# 45021      Gold
# 45103      Gold
# 45187      Gold
# 45280      Gold
#
# [645 rows x 15 columns]

# %% [markdown]
# Os valores corretos podem ser vistos em Event, então criaremos uma coluna com base em Event para saber se o evento é feminimo ou masculino.

# %%
df["Men"] = df["Event"].str.contains("Men")
df["Mixed"] = df["Event"].str.contains("Mixed")
df["Women"] = df["Event"].str.contains("Women")

# %%
df[(df["Sex"] == "Vic vai te dar um socao") & ((df["Women"] ==True) | (df["Mixed"] ==True))]
# Out:
#        Athlete_ID                                 Name  \
# 959          3864          Thomas James "Tom" Anderson
# 1837         6748                    Klaus Baard Baess
# 2537         9041                Colin Kenneth Beashel
# 2920        10128    Stephen DeLancey "Steve" Benjamin
# 3599        12095                      Henrik Blakskjr
# 4899        15774            Pierre mile Ernest Brunet
# 5438        17391               Stephen "Steve" Calder
# 8721        28332                       Christian Dick
# 10253       32894                   John Filip Ericson
# 10939       34909      Johan Martin Ferner (Jacobsen-)
# 11710       36987                   Kevin John Freeman
# 14373       44785                         Norbert Hahn
# 15779       48661  Johannes Jozef Antonius "Johan" Hin
# 17732       54439               Poul Richard Hj Jensen
# 25619       77058                   Wolfgang Mayrhofer
# 26112       78412        Aleksandr Remmovich Melentyev
# 27577       83016             Rolf Theodor Heinz Mulka
# 28507       85991                     Ingar H. Nielsen
# 29170       87869                       David O'Connor
# 29237       88079                     Rolf Oesterreich
# 31722       95858                     Nikolai Poljakov
# 34843      105287                 Carl Gustav Sandblom
# 41352      123897           Alberto Vldes Lacarra, Jr.
# 43938      130880                  Peter Arthur Wilson
# 43985      130999                   Hans Gnter Winkler
#
#                            Sex   Age  Height  Weight            Team  NOC  \
# 959    Vic vai te dar um socao  33.0  183.00   89.00       Australia  AUS
# 1837   Vic vai te dar um socao  23.0  177.22   73.48            Snap  DEN
# 2537   Vic vai te dar um socao  36.0  181.00   87.00       Australia  AUS
# 2920   Vic vai te dar um socao  28.0  175.00   59.00   United States  USA
# 3599   Vic vai te dar um socao  29.0  194.00   90.00         Denmark  DEN
# 4899   Vic vai te dar um socao  29.0  168.00   73.48          France  FRA
# 5438   Vic vai te dar um socao  26.0  204.00   96.00          Canada  CAN
# 8721   Vic vai te dar um socao  36.0  177.22   73.48         Fornebo  NOR
# 10253  Vic vai te dar um socao  29.0  177.22   73.48         Kitty-1  SWE
# 10939  Vic vai te dar um socao  24.0  177.22   73.48     Elisabeth X  NOR
# 11710  Vic vai te dar um socao  22.0  171.00   68.00   United States  USA
# 14373  Vic vai te dar um socao  26.0  180.00   73.00  East Germany-1  GDR
# 15779  Vic vai te dar um socao  21.0  177.22   73.48  Beatrijs III-1  NED
# 17732  Vic vai te dar um socao  36.0  183.00   78.00         Denmark  DEN
# 25619  Vic vai te dar um socao  22.0  181.00   71.00         Austria  AUT
# 26112  Vic vai te dar um socao  26.0  177.00   82.00    Soviet Union  URS
# 27577  Vic vai te dar um socao  32.0  184.00   87.00        Macky VI  GER
# 28507  Vic vai te dar um socao  38.0  177.22   73.48            Bera  NOR
# 29170  Vic vai te dar um socao  38.0  180.00   77.00   United States  USA
# 29237  Vic vai te dar um socao  23.0  184.00   75.00  East Germany-1  GDR
# 31722  Vic vai te dar um socao  29.0  185.00   98.00    Soviet Union  URS
# 34843  Vic vai te dar um socao  19.0  177.22   73.48          Sylvia  SWE
# 41352  Vic vai te dar um socao  29.0  178.00   65.00          Mexico  MEX
# 43938  Vic vai te dar um socao  20.0  185.00   80.00        Zimbabwe  ZIM
# 43985  Vic vai te dar um socao  29.0  174.00   72.00         Germany  GER
#
#              Games  Year  Season         City           Sport  \
# 959    1972 Summer  1972  Summer       Munich         Sailing
# 1837   1948 Summer  1948  Summer       London         Sailing
# 2537   1996 Summer  1996  Summer      Atlanta         Sailing
# 2920   1984 Summer  1984  Summer  Los Angeles         Sailing
# 3599   2000 Summer  2000  Summer       Sydney         Sailing
# 4899   1932 Winter  1932  Winter  Lake Placid  Figure Skating
# 5438   1984 Summer  1984  Summer  Los Angeles         Sailing
# 8721   1920 Summer  1920  Summer    Antwerpen         Sailing
# 10253  1912 Summer  1912  Summer    Stockholm         Sailing
# 10939  1952 Summer  1952  Summer     Helsinki         Sailing
# 11710  1964 Summer  1964  Summer        Tokyo   Equestrianism
# 14373  1980 Winter  1980  Winter  Lake Placid            Luge
# 15779  1920 Summer  1920  Summer    Antwerpen         Sailing
# 17732  1980 Summer  1980  Summer       Moskva         Sailing
# 25619  1980 Summer  1980  Summer       Moskva         Sailing
# 26112  1980 Summer  1980  Summer       Moskva        Shooting
# 27577  1960 Summer  1960  Summer         Roma         Sailing
# 28507  1924 Summer  1924  Summer        Paris         Sailing
# 29170  2000 Summer  2000  Summer       Sydney   Equestrianism
# 29237  1976 Winter  1976  Winter    Innsbruck  Figure Skating
# 31722  1980 Summer  1980  Summer       Moskva         Sailing
# 34843  1928 Summer  1928  Summer    Amsterdam         Sailing
# 41352  1980 Summer  1980  Summer       Moskva   Equestrianism
# 43938  1980 Summer  1980  Summer       Moskva         Sailing
# 43985  1956 Summer  1956  Summer    Stockholm   Equestrianism
#
#                                              Event     Medal    Men  Mixed  \
# 959            Sailing Mixed Three Person Keelboat      Gold  False   True
# 1837           Sailing Mixed Three Person Keelboat    Bronze  False   True
# 2537             Sailing Mixed Two Person Keelboat    Bronze  False   True
# 2920               Sailing Mixed Two Person Dinghy    Silver  False   True
# 3599           Sailing Mixed Three Person Keelboat      Gold  False   True
# 4899                    Figure Skating Mixed Pairs      Gold  False   True
# 5438           Sailing Mixed Three Person Keelboat    Bronze  False   True
# 8721                        Sailing Mixed 7 metres    Silver  False   True
# 10253                      Sailing Mixed 10 metres      Gold  False   True
# 10939                       Sailing Mixed 6 metres    Silver  False   True
# 11710    Equestrianism Mixed Three-Day Event, Team    Silver  False   True
# 14373                   Luge Mixed (Men)'s Doubles      Gold   True   True
# 15779                        Sailing Mixed 12 foot      Gold  False   True
# 17732          Sailing Mixed Three Person Keelboat      Gold  False   True
# 25619              Sailing Mixed One Person Dinghy    Silver  False   True
# 26112        Shooting Mixed Free Pistol, 50 metres      Gold  False   True
# 27577  Sailing Mixed Two Person Heavyweight Dinghy    Bronze  False   True
# 28507                       Sailing Mixed 8 metres      Gold  False   True
# 29170    Equestrianism Mixed Three-Day Event, Team    Bronze  False   True
# 29237                   Figure Skating Mixed Pairs    Silver  False   True
# 31722          Sailing Mixed Three Person Keelboat    Silver  False   True
# 34843                       Sailing Mixed 8 metres    Bronze  False   True
# 41352      Equestrianism Mixed Jumping, Individual  No Medal  False   True
# 43938              Sailing Mixed One Person Dinghy  No Medal  False   True
# 43985            Equestrianism Mixed Jumping, Team      Gold  False   True
#
#        Women
# 959    False
# 1837   False
# 2537   False
# 2920   False
# 3599   False
# 4899   False
# 5438   False
# 8721   False
# 10253  False
# 10939  False
# 11710  False
# 14373  False
# 15779  False
# 17732  False
# 25619  False
# 26112  False
# 27577  False
# 28507  False
# 29170  False
# 29237  False
# 31722  False
# 34843  False
# 41352  False
# 43938  False
# 43985  False

# %%
df[(df["Sex"] == "P&D >> Comunidade") & ((df["Men"] ==True) | (df["Mixed"] ==True))]
# Out:
#        Athlete_ID                                       Name  \
# 2582         9154          Laura Bechtolsheimer (-Tomlinson)
# 2751         9561               Tanith Jessica Louise Belbin
# 4903        15776       Andre Marguerite Blanche Brunet-Joly
# 7915        25713                      Meryl Elizabeth Davis
# 13717       43025      Oksana Vladimirovna "Pasha" Grishchuk
# 16459       50501   Olena Eduardivna Hrushyna (-Honcharova-)
# 19026       58265                  Oksana Borisovna Kazakova
# 22807       68693                       Karen Lende O'Connor
# 31229       94284  Yelena Vladimirovna Petushkova (-Brumel-)
# 31320       94497    Zara Anne Elizabeth Phillips (-Tindall)
# 37275      112260                                 Gina Smith
#
#                      Sex   Age      Height  Weight             Team  NOC  \
# 2582   P&D >> Comunidade  27.0  169.000000   56.00    Great Britain  GBR
# 2751   P&D >> Comunidade  21.0  167.000000   52.00  United States-1  USA
# 4903   P&D >> Comunidade  30.0  165.000000   73.48           France  FRA
# 7915   P&D >> Comunidade  23.0  160.000000   49.00  United States-1  USA
# 13717  P&D >> Comunidade  26.0  164.000000   50.00         Russia-1  RUS
# 16459  P&D >> Comunidade  31.0  168.000000   52.00        Ukraine-1  UKR
# 19026  P&D >> Comunidade  22.0  158.000000   48.00         Russia-1  RUS
# 22807  P&D >> Comunidade  42.0  168.000000   55.00    United States  USA
# 31229  P&D >> Comunidade  27.0  160.000000   65.00     Soviet Union  URS
# 31320  P&D >> Comunidade  31.0  177.218534   64.00    Great Britain  GBR
# 37275  P&D >> Comunidade  30.0  175.000000   66.00           Canada  CAN
#
#              Games  Year  Season         City           Sport  \
# 2582   2012 Summer  2012  Summer       London   Equestrianism
# 2751   2006 Winter  2006  Winter       Torino  Figure Skating
# 4903   1932 Winter  1932  Winter  Lake Placid  Figure Skating
# 7915   2010 Winter  2010  Winter    Vancouver  Figure Skating
# 13717  1998 Winter  1998  Winter       Nagano  Figure Skating
# 16459  2006 Winter  2006  Winter       Torino  Figure Skating
# 19026  1998 Winter  1998  Winter       Nagano  Figure Skating
# 22807  2000 Summer  2000  Summer       Sydney   Equestrianism
# 31229  1968 Summer  1968  Summer  Mexico City   Equestrianism
# 31320  2012 Summer  2012  Summer       London   Equestrianism
# 37275  1988 Summer  1988  Summer        Seoul   Equestrianism
#
#                                            Event   Medal    Men  Mixed  Women
# 2582    Equestrianism Mixed Dressage, Individual  Bronze  False   True  False
# 2751            Figure Skating Mixed Ice Dancing  Silver  False   True  False
# 4903                  Figure Skating Mixed Pairs    Gold  False   True  False
# 7915            Figure Skating Mixed Ice Dancing  Silver  False   True  False
# 13717           Figure Skating Mixed Ice Dancing    Gold  False   True  False
# 16459           Figure Skating Mixed Ice Dancing  Bronze  False   True  False
# 19026                 Figure Skating Mixed Pairs    Gold  False   True  False
# 22807  Equestrianism Mixed Three-Day Event, Team  Bronze  False   True  False
# 31229         Equestrianism Mixed Dressage, Team  Silver  False   True  False
# 31320  Equestrianism Mixed Three-Day Event, Team  Silver  False   True  False
# 37275         Equestrianism Mixed Dressage, Team  Bronze  False   True  False

# %% [markdown]
# Percebemos acima que quando a coluna Sex é "P&D >> Comunidade" deveria ser "F" e quando é "Vic vai te dar um socao" deveria ser "M".

# %%
df["Sex"] = df["Sex"].map(lambda x: "M" if (x == "MALE" or x == "Vic vai te dar um socao") else "F" if (x == "FEMALE" or x == "P&D >> Comunidade") else x)

# %%
df.Sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df.drop(columns=["Men", "Mixed", "Women"], inplace = True)
df.head()
# Out:
#    Athlete_ID                      Name Sex   Age  Height  Weight  \
# 0           4      Edgar Lindenau Aabye   M  34.0  177.22   73.48
# 1           6           Per Knut Aaland   M  31.0  188.00   75.00
# 2          15      Arvo Ossian Aaltonen   M  30.0  177.22   73.48
# 3          15      Arvo Ossian Aaltonen   M  30.0  177.22   73.48
# 4          16  Juhamatti Tapio Aaltonen   M  28.0  184.00   85.00
#
#              Team  NOC        Games  Year  Season         City  \
# 0  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 1   United States  USA  1992 Winter  1992  Winter  Albertville
# 2         Finland  FIN  1920 Summer  1920  Summer    Antwerpen
# 3         Finland  FIN  1920 Summer  1920  Summer    Antwerpen
# 4         Finland  FIN  2014 Winter  2014  Winter        Sochi
#
#                   Sport                                              Event  \
# 0            Tug-Of-War                        Tug-Of-War Men's Tug-Of-War
# 1  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 2              Swimming             Swimming Men's 200 metres Breaststroke
# 3              Swimming             Swimming Men's 400 metres Breaststroke
# 4            Ice Hockey                        Ice Hockey Men's Ice Hockey
#
#       Medal
# 0      Gold
# 1  No Medal
# 2    Bronze
# 3    Bronze
# 4    Bronze

# %% [markdown]
# Mais um problema resolvido. Vamos para as próximas colunas.
# A coluna Team será desnecessária para a nossa análise, pois além de possuir dados incoerentes, não encontrei uma forma de padroniza-la de forma coerente. Mas isso não é um problema já que existe a coluna NOC, que me permite localizar os atletas por nacionalidade. Desse modo, iremos excluir tal coluna.

# %%
np.sort(df.Team.unique())
# Out:
# array(['#ForaBolsonaro', 'A North American Team', 'Afghanistan',
#        'Alain IV', 'Albania', 'Algeria', 'Ali-Baba II',
#        'Amateur Athletic Association', 'Amstel Amsterdam', 'Ancora',
#        'Andorra', 'Angelita', 'Angola', 'Antigua and Barbuda',
#        'Antwerpia V', 'Aphrodite', 'Argentina', 'Argentina-2',
#        'Argonaut Rowing Club', 'Armenia', 'Aruba', 'Aschenbrodel',
#        'Atalanta Boat Club-1', 'Atalanta Boat Club-2', 'Athens-2',
#        'Atlanta', 'Australasia', 'Australia', 'Australia-1',
#        'Australia-2', 'Australia-3', 'Australia/Great Britain', 'Austria',
#        'Austria-1', 'Austria-2', 'Azerbaijan', 'BLO Polo Club, Rugby',
#        'Baby-1', 'Bagatelle Polo Club, Paris', 'Bahamas', 'Bahrain',
#        'Ballerina IV', 'Bamba', 'Barbados', 'Barion/Bari-2', 'Barrenjoey',
#        'Beatrijs III-1', 'Belarus', 'Belgium', 'Belgium-1', 'Belize',
#        'Bem II', 'Benin', 'Bera', 'Berliner Ruderclub',
#        'Berliner Ruderverein von 1876-2', 'Bermuda', 'Bingo', 'Bissbi',
#        'Bluebottle', 'Bohemia', 'Bohemia-2', 'Bohemia/Great Britain',
#        'Bona Fide', 'Bonaparte', 'Bonzo', 'Boreas-2',
#        'Bosnia and Herzegovina', 'Boston Archers', 'Botswana', 'Brazil',
#        'Brazil-1', 'Brazil-2', 'British Virgin Islands',
#        'Brussels Swimming and Water Polo Club', 'Brynhild-2',
#        'Bucintoro Venezia', 'Bucintoro Venezia-1', 'Bulgaria', 'Buraddoo',
#        'Burkina Faso', 'Burundi', 'Cambodia',
#        'Cambridge University Boat Club-2', 'Cameroon', 'Camille',
#        'Canada', 'Canada-1', 'Canada-2', 'Caprice', 'Carabinier-15',
#        'Cayman Islands', 'Central Turnverein, Chicago',
#        'Century Boat Club-1', "Cercle de l'Aviron Roubaix-4", 'Ceres II',
#        'Chicago Athletic Association', 'Chicago Athletic Association-2',
#        'Chile', 'China', 'China-1', 'China-2', 'China-3',
#        'Chinese Taipei', "Christian Brothers' College-1", 'Chuckles',
#        'Cicely-1', 'Cincinnati Archers', 'Clearwater',
#        'Club Nautique de Lyon-2', 'Cobweb-1', 'Colombia', 'Comanche',
#        'Combine', 'Complex II', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Cook Islands', 'Cornwall', 'Costa Rica', "Cote d'Ivoire",
#        'Crabe II-1', 'Crabe II-4', 'Crete', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Czech Republic-1', 'Czech Republic-2',
#        'Czechoslovakia', 'Czechoslovakia-1', 'Czechoslovakia-2', 'Danuta',
#        'Demi-Mondaine-15', 'Denmark', 'Denmark-1', 'Denmark-2',
#        'Denmark/Sweden', 'Deutscher Schwimm Verband Berlin',
#        'Devon and Somerset Wanderers', 'Digby', 'Djibouti', 'Djinn',
#        'Dominica', 'Dominican Republic', 'Don Schufro', 'Dormy-1',
#        'East Germany', 'East Germany-1', 'East Germany-2', 'Ecuador',
#        'Edelweiss II-1', 'Egypt', 'El Salvador', 'Eleda', 'Elisabeth V',
#        'Elisabeth X', 'Elsie', 'Elvis Va', 'Emily', 'Encore', 'England',
#        'England-1', 'Eritrea', 'Erna Signe', 'Espadarte', 'Esterel-1',
#        'Estonia', 'Ethiopia', 'Ethnikos Gymnastikos Syllogos',
#        'Falcon IV', 'Fantlet-7', 'Favorite Hammonia-3', 'Favorite-1',
#        'Federated States of Micronesia', 'Femur-1', 'Fiji', 'Finland',
#        'Formosa', 'Fornebo', 'Foxhunters Hurlingham', 'Fram', 'France',
#        'France-1', 'France-2', 'France-3', 'France/Great Britain',
#        'Frankfurt Club', 'Frimousse', 'Gabon', 'Galejan', 'Galerna',
#        'Gallant', 'Gallia II', 'Galt Football Club', 'Gambia', 'Gem',
#        'Gem IV', 'Georgia', 'Germania II',
#        'Germania Ruder Club, Hamburg-2', 'Germany', 'Germany-1',
#        'Germany-2', 'Germany-3', 'Ghana', 'Gitana-2', 'Gitana-21',
#        'Glider', 'Great Britain', 'Great Britain-1', 'Great Britain-2',
#        'Great Britain-3', 'Great Britain/Germany', 'Greece', 'Greece-1',
#        'Greece-2', 'Grenada', 'Grifo IV', 'Guam', 'Guatemala', 'Guinea',
#        'Gustel X', 'Guyana', 'Guyoni', 'Gwendoline-2', 'Gyrinus-1',
#        'Haiti', 'Hannover', 'Heatherbell', 'Heira II', 'Hera-1',
#        'Heroine', 'Hi-Hi', 'Hilarius', 'Hojwa', 'Hollandia', 'Honduras',
#        'Hong Kong', 'Hong Kong-2', 'Humbug V', 'Hungary', 'Hungary-1',
#        'Hungary-2', 'Hurlingham-2', 'Iceland',
#        'Independent Rowing Club-3', 'India', 'India-1',
#        'Individual Olympic Athletes', 'Indonesia', 'Indonesia-1', 'Iran',
#        'Iraq', 'Ireland', 'Ireland-1', 'Ireland-2', 'Ireland-3', 'Irene',
#        'Israel', 'Italia', 'Italy', 'Italy-1', 'Italy-2', 'Jamaica',
#        'Japan', 'Japan-1', 'Japan-2', 'Jest', 'Jo', 'Jordan', 'Joy',
#        'Jupiter', 'K Division Metropolitan Police Team-3', 'Kathleen',
#        'Kazakhstan', 'Kenya', 'Kerstin-1', 'Kiribati', 'Kitty-1',
#        'Kosovo', 'Kristiania Roklub-1', 'Kullan', 'Kurush II', 'Kuwait',
#        'Kyrgyzstan', "L'Aile VI", 'Lady C', 'Lalage',
#        'Large boat, Central Naval Prep School "Poros"-1', 'Latvia',
#        'Latvia-1', 'Latvia-2', 'Laurea-1', 'Leander Club #1-1',
#        'Leander Club #2-2', 'Leander Club-1', 'Leander Club-2', 'Lebanon',
#        'Lerina', 'Lesotho', 'Libellule de Paris', 'Liberia', 'Libya',
#        'Liechtenstein', 'Life boat naval ship "Spetsai"-1', 'Lithuania',
#        'Liverpool Police Team-2', 'Llanoria', 'London City Police-1',
#        'Lucky Girl-1', 'Ludwigshafener Ruder Verein-1',
#        'Ludwigshafener Ruderverein', 'Lully II', 'Luxembourg', 'Lyn-2',
#        "Ma'Lindo", 'Mac Miche', 'Macedonia', 'Macky VI', 'Madagascar',
#        'Magda IX', 'Magdalen College Boat Club-1', 'Malawi', 'Malaya',
#        'Malaysia', 'Malaysia-1', 'Malaysia-2', 'Malta', 'Margaret',
#        'Marinai della nave da guerra "Varese"', 'Marmi II-1',
#        'Marshall Islands', 'Martha-1', 'Mascotte', 'Mauritania',
#        'Mauritius', 'May Be', 'Merope', 'Merope III', 'Mexico',
#        'Mignon-3', 'Milwaukee Athletic Club-1', 'Minerva Amsterdam',
#        'Minotaur', 'Missouri Athletic Club-3', 'Mohawk Indians-2',
#        'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
#        'Moseley Wanderers', 'Mosk II', 'Mouchette-2',
#        'Mound City Rowing Club-2', 'Mozambique', 'Mutafo', 'Myanmar',
#        'Nadine', 'Naiad', 'Namibia', 'Namoussa', 'Nauru', 'Nepal',
#        'Netherlands', 'Netherlands Antilles', 'Netherlands-1',
#        'New College, Oxford-2', 'New York Athletic Club',
#        'New York Athletic Club #1-1', 'New York Athletic Club-1',
#        'New York Turnverein, New York', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'Nina', 'Nina Claire-2', 'Nirefs', 'Norna',
#        'North Korea', 'North Korea-1', 'North Yemen', 'Norway',
#        'Norway-1', 'Norway-2', 'Nrnberg', 'Nurdug II',
#        'Nykjbings paa Falster', 'Olle', 'Oman', 'Omas Helliniki P. S.',
#        'Omilos Ereton Smyrnis', 'Oranje', 'Orion', 'Ormsund Roklub-2',
#        'Osborne Swimming Club, Manchester', 'Pakistan', 'Palestine',
#        'Pan', 'Panama', 'Pandora', 'Papua New Guinea', 'Paraguay',
#        'Passaic Turnverein, Passaic', 'Peiraikos Syndesmos-2', 'Peru',
#        'Phalainis ton Thorichtou "Hydra"-2',
#        'Philadelphia Turngemeinde, Philadelphia', 'Philippines',
#        'Pistoja/Firenze', 'Poland', 'Poland-1', 'Poland-2',
#        'Polyteknisk Roklub-1', 'Portugal', 'Potomac Archers', 'Potsdam',
#        'Puerto Rico', 'Pupilles de Neptune de Lille #2-1',
#        'Pupilles de Neptune de Lille-1', 'Qatar', 'Quand-Mme-2',
#        'Racing Club de France', 'Raili', 'Ralia',
#        'Ravenswood Boat Club-2', 'Refugee Olympic Athletes', 'Rhodesia',
#        'Roddklubben af 1912-1', 'Roehampton-1', 'Roklubb Kbnhavn-2',
#        'Romania', 'Romania-1', 'Rose Pompon', 'Rostock',
#        'Rowing Club Castillon-3', 'Royal Club Nautique de Gand', 'Rush V',
#        'Rush VII', 'Russia', 'Russia-1', 'Russia-2', 'Russia-3', 'Rwanda',
#        'Saar', 'Saint Kitts and Nevis',
#        'Saint Vincent and the Grenadines', 'Salinero', 'Samoa',
#        'San Marino', 'Sans Atout-1', 'Santa Maria', 'Sarcelle-3',
#        'Satchmo', 'Saudi Arabia', 'Scamasaxe-2', 'Scamasaxe-3', 'Scotia',
#        'Scotland', 'Scotland-3', 'Sea Dog-2', 'Seawanhaka Boat Club-1',
#        'Senegal', 'Serbia', 'Serbia and Montenegro', 'Shrew II',
#        'Sierra Leone', 'Sif', 'Sildra-1', 'Silja', 'Singapore', 'Sirene',
#        'Skum', 'Slaghoken', 'Slaghoken II', 'Slovakia', 'Slovakia-2',
#        'Slovenia', 'Smyrna', 'Snap', 'Societ Nautique de la Marne-1',
#        'Socit Nautique de Bayonne', 'Socit Nautique de Bayonne-1',
#        'Socit Nautique de Bayonne-2',
#        'Socit Nautique de la Basse Seine-1',
#        'Socit Nautique de la Basse Seine-2', 'Solomon Islands',
#        'Sonja II', 'Sorais-2', 'South Africa', 'South Korea',
#        'South Korea-1', 'South Korea-2',
#        'South St Louis Turnverein, St Louis', 'Soviet Union',
#        'Soviet Union-1', 'Soviet Union-2', 'Soviet Union-3', 'Spain',
#        'Spain-1', 'Spain-2', 'Sri Lanka',
#        'St. Louis Amateur Athletic Association',
#        'St. Louis Southwest Turnverein #1-2',
#        'St. Louis Southwest Turnverein #2-3', 'St. Rose-2', 'Starita',
#        'Stella-2', 'Sudan', 'Sunrise', 'Sunshine', 'Suriname',
#        'Swaziland', 'Sweden', 'Sweden-1', 'Sweden-2', 'Sweden-3',
#        'Swedish Star', 'Swift', 'Switzerland', 'Switzerland-1',
#        'Switzerland-2', 'Sylvia', 'Symphony', 'Syria', 'Taifun',
#        'Tajikistan', 'Tan-Fe-Pah', 'Tango', 'Tanzania', 'Thailand',
#        'Thames Rowing Club', 'Thessalonki-1', 'Tip', 'Togo', 'Tonga',
#        'Tornado', 'Toronto Argonauts',
#        'Trans-Mississippi Golf Association-2', 'Trinidad and Tobago',
#        'Tritons Lillois-2', 'Tunisia', 'Turkey',
#        'Turnverein Vorwrts, Chicago', 'Turquoise-1', 'Tutti V', 'USFSA',
#        'Ubu', 'Uganda', 'Ukraine', 'Ukraine-1', 'Ukraine-2',
#        'Unified Team', 'Unified Team-1', 'Unified Team-2',
#        'Union des Socits Franais de Sports Athletiques',
#        'United Arab Emirates', 'United Arab Republic', 'United States',
#        'United States Golf Association-3', 'United States Virgin Islands',
#        'United States Virgin Islands-2', 'United States-1',
#        'United States-2', 'United States-3', 'United States-4',
#        'United States/France', 'United States/Great Britain',
#        'Univ. of Brussels', 'Upton Park FC', 'Uruguay', 'Uzbekistan',
#        'Uzbekistan-1', 'Venezuela', 'Venilia', 'Vesper Boat Club',
#        'Vietnam', 'Vinga-1', 'Vision', 'Wales-4', 'Wannsee', 'Web II',
#        'West Germany', 'West Germany-1', 'West Germany-2',
#        'West Indies Federation', 'Western Golf Association-1',
#        'Western Rowing Club-3', 'White Lady', 'Widgeon', 'Willem-Six',
#        'Winnipeg Shamrocks-1', 'Xantippa', 'Yemen', 'Yeoman V',
#        'Yugoslavia', 'Zambia', 'Zimbabwe', 'Zut'], dtype=object)

# %%
df.drop(columns = "Team", inplace = True)
df.head()
# Out:
#    Athlete_ID                      Name Sex   Age  Height  Weight  NOC  \
# 0           4      Edgar Lindenau Aabye   M  34.0  177.22   73.48  DEN
# 1           6           Per Knut Aaland   M  31.0  188.00   75.00  USA
# 2          15      Arvo Ossian Aaltonen   M  30.0  177.22   73.48  FIN
# 3          15      Arvo Ossian Aaltonen   M  30.0  177.22   73.48  FIN
# 4          16  Juhamatti Tapio Aaltonen   M  28.0  184.00   85.00  FIN
#
#          Games  Year  Season         City                 Sport  \
# 0  1900 Summer  1900  Summer        Paris            Tug-Of-War
# 1  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2  1920 Summer  1920  Summer    Antwerpen              Swimming
# 3  1920 Summer  1920  Summer    Antwerpen              Swimming
# 4  2014 Winter  2014  Winter        Sochi            Ice Hockey
#
#                                                Event     Medal
# 0                        Tug-Of-War Men's Tug-Of-War      Gold
# 1  Cross Country Skiing Men's 10/15 kilometres Pu...  No Medal
# 2             Swimming Men's 200 metres Breaststroke    Bronze
# 3             Swimming Men's 400 metres Breaststroke    Bronze
# 4                        Ice Hockey Men's Ice Hockey    Bronze

# %%
np.sort(df.NOC.unique())
# Out:
# array(['AFG', 'AHO', 'ALB', 'ALG', 'AND', 'ANG', 'ANT', 'ANZ', 'ARG',
#        'ARM', 'ARU', 'AUS', 'AUT', 'AZE', 'BAH', 'BAR', 'BDI', 'BEL',
#        'BEN', 'BER', 'BIH', 'BIZ', 'BLR', 'BOH', 'BOT', 'BRA', 'BRN',
#        'BUL', 'BUR', 'CAM', 'CAN', 'CAY', 'CGO', 'CHI', 'CHN', 'CIV',
#        'CMR', 'COD', 'COK', 'COL', 'CRC', 'CRO', 'CRT', 'CUB', 'CYP',
#        'CZE', 'DEN', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'ERI', 'ESA',
#        'ESP', 'EST', 'ETH', 'EUN', 'FIJ', 'FIN', 'FRA', 'FRG', 'FSM',
#        'GAB', 'GAM', 'GBR', 'GDR', 'GEO', 'GER', 'GHA', 'GRE', 'GRN',
#        'GUA', 'GUI', 'GUM', 'GUY', 'HAI', 'HKG', 'HON', 'HUN', 'INA',
#        'IND', 'IOA', 'IRI', 'IRL', 'IRQ', 'ISL', 'ISR', 'ISV', 'ITA',
#        'IVB', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KIR', 'KOR',
#        'KOS', 'KSA', 'KUW', 'LAT', 'LBA', 'LBR', 'LES', 'LIB', 'LIE',
#        'LTU', 'LUX', 'MAD', 'MAL', 'MAR', 'MAS', 'MAW', 'MDA', 'MEX',
#        'MGL', 'MHL', 'MKD', 'MLT', 'MNE', 'MON', 'MOZ', 'MRI', 'MTN',
#        'MYA', 'NAM', 'NCA', 'NED', 'NEP', 'NGR', 'NIG', 'NOR', 'NRU',
#        'NZL', 'OMA', 'PAK', 'PAN', 'PAR', 'PER', 'PHI', 'PLE', 'PNG',
#        'POL', 'POR', 'PRK', 'PUR', 'QAT', 'RHO', 'ROT', 'ROU', 'RSA',
#        'RUS', 'RWA', 'SAA', 'SAM', 'SCG', 'SEN', 'SGP', 'SKN', 'SLE',
#        'SLO', 'SMR', 'SOL', 'SRB', 'SRI', 'SUD', 'SUI', 'SUR', 'SVK',
#        'SWE', 'SWZ', 'SYR', 'TAN', 'TCH', 'TGA', 'THA', 'TJK', 'TOG',
#        'TPE', 'TTO', 'TUN', 'TUR', 'UAE', 'UAR', 'UGA', 'UKR', 'URS',
#        'URU', 'USA', 'UZB', 'VEN', 'VIE', 'VIN', 'WIF', 'YAR', 'YEM',
#        'YUG', 'ZAM', 'ZIM'], dtype=object)

# %%
df = df.merge(noc_regions, on="NOC")
df.rename(columns={'region': 'Country'}, inplace = True)
df.loc[df["NOC"] == "ROT","Country"] = "Refugee Olympic Team"
df.drop(columns = ["NOC","notes"], inplace = True)
df.head()
# Out:
#    Athlete_ID                              Name Sex   Age  Height  Weight  \
# 0           4              Edgar Lindenau Aabye   M  34.0  177.22   73.48
# 1         734                Otto Mnsted Acthon   M  30.0  177.22   73.48
# 2         734                Otto Mnsted Acthon   M  34.0  177.22   73.48
# 3        2347  Georg Albert Christian Albertsen   M  30.0  177.22   73.48
# 4        2882           Ejler Arild Emil Allert   M  30.0  177.22   73.48
#
#          Games  Year  Season       City          Sport  \
# 0  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 1  1948 Summer  1948  Summer     London  Equestrianism
# 2  1952 Summer  1952  Summer   Helsinki  Equestrianism
# 3  1920 Summer  1920  Summer  Antwerpen     Gymnastics
# 4  1912 Summer  1912  Summer  Stockholm         Rowing
#
#                                              Event     Medal  Country
# 0                      Tug-Of-War Men's Tug-Of-War      Gold  Denmark
# 1          Equestrianism Men's Jumping, Individual  No Medal  Denmark
# 2  Equestrianism Men's Three-Day Event, Individual  No Medal  Denmark
# 3    Gymnastics Men's Team All-Around, Free System      Gold  Denmark
# 4              Rowing Men's Coxed Fours, Inriggers      Gold  Denmark

# %% [markdown]
# Agora, analisaremos a coluna Season.

# %%
df.Season.unique()
# Out:
# array(['Summer', 'Winter', '#ForaBolsonaro', 'Ele nunca', 'Ele não'],
#       dtype=object)

# %% [markdown]
# Como possuímos valores invalidos, podemos substituir a coluna pelos ultimos caracteres da coluna Games

# %%
df["Season"] = df["Games"].str[5:]
df["Season"].unique()
# Out:
# array(['Summer', 'Winter'], dtype=object)

# %% [markdown]
# Por último análisaremos a coluna Medal.

# %%
df["Medal"].unique()
# Out:
# array(['Gold', 'No Medal', 'Bronze', 'Silver', 'Nelson'], dtype=object)

# %%
df[df["Medal"] == "Nelson"]
# Out:
#        Athlete_ID                                         Name Sex   Age  \
# 813          5971                     Seimone Delicia Augustus   F  28.0
# 980          9291       Barbara Jane "B. J." Bedford (-Miller)   F  27.0
# 1600        22274        Tiffany Lisa Cohen (-Adams, -Lalonde)   F  18.0
# 2788        45332               Sarah Kathryn Hammer (-Sparks)   F  28.0
# 3185        52060                                    Kyoko Ina   F  25.0
# ...           ...                                          ...  ..   ...
# 44206      103888       Olga Sergeyevna Rypakova (Alekseyeva-)   F  27.0
# 44706       65376  Anastasia Vladimirovna Kuzmina (Shipulina-)   F  25.0
# 44787       37745                              Savatheda Fynes   F  25.0
# 44848        7874                           Sonja Barjaktarovi   F  25.0
# 44928       77079                       Klementina "Tina" Maze   F  26.0
#
#        Height  Weight        Games  Year  Season         City           Sport  \
# 813     183.0   74.00  2012 Summer  2012  Summer       London      Basketball
# 980     172.0   61.00  2000 Summer  2000  Summer       Sydney        Swimming
# 1600    175.0   63.00  1984 Summer  1984  Summer  Los Angeles        Swimming
# 2788    171.0   65.00  2012 Summer  2012  Summer       London         Cycling
# 3185    152.0   42.00  1998 Winter  1998  Winter       Nagano  Figure Skating
# ...       ...     ...          ...   ...     ...          ...             ...
# 44206   183.0   62.00  2012 Summer  2012  Summer       London       Athletics
# 44706   180.0   67.00  2010 Winter  2010  Winter    Vancouver        Biathlon
# 44787   165.0   73.48  2000 Summer  2000  Summer       Sydney       Athletics
# 44848   180.0   74.00  2012 Summer  2012  Summer       London        Handball
# 44928   172.0   68.00  2010 Winter  2010  Winter    Vancouver   Alpine Skiing
#
#                                               Event   Medal     Country
# 813                   Basketball Women's Basketball  Nelson         USA
# 980    Swimming Women's 4 x 100 metres Medley Relay  Nelson         USA
# 1600          Swimming Women's 400 metres Freestyle  Nelson         USA
# 2788                         Cycling Women's Omnium  Nelson         USA
# 3185                     Figure Skating Mixed Pairs  Nelson         USA
# ...                                             ...     ...         ...
# 44206                 Athletics Women's Triple Jump  Nelson  Kazakhstan
# 44706        Biathlon Women's 10 kilometres Pursuit  Nelson    Slovakia
# 44787        Athletics Women's 4 x 100 metres Relay  Nelson     Bahamas
# 44848                     Handball Women's Handball  Nelson  Montenegro
# 44928            Alpine Skiing Women's Giant Slalom  Nelson    Slovenia
#
# [166 rows x 14 columns]

# %% [markdown]
# Apenas pelo dataset, não conseguimos verificar o real valor das medalhas, portanto admitiremos os valores inválidos como "No Medal".

# %%
df.loc[df["Medal"]== 'Nelson',"Medal"] = "No Medal"
df["Medal"].unique()
# Out:
# array(['Gold', 'No Medal', 'Bronze', 'Silver'], dtype=object)

# %% [markdown]
# Como ja verificamos todas as colunas que nos interessariam, agora excluiremos as colunas que não utilizaremos para analisar.

# %%
df.drop(columns = ["Athlete_ID", "Games", "City", "Event"], inplace = True)

# %% [markdown]
# ### Dataset Limpo

# %%
df.head(30)
# Out:
#                                            Name Sex   Age  Height  Weight  \
# 0                          Edgar Lindenau Aabye   M  34.0  177.22   73.48
# 1                            Otto Mnsted Acthon   M  30.0  177.22   73.48
# 2                            Otto Mnsted Acthon   M  34.0  177.22   73.48
# 3              Georg Albert Christian Albertsen   M  30.0  177.22   73.48
# 4                       Ejler Arild Emil Allert   M  30.0  177.22   73.48
# 5                 Aage Jrgen Christian Andersen   M  22.0  177.22   73.48
# 6                         Anders Peter Andersen   M  26.0  177.22   70.00
# 7                             Anja Jul Andersen   F  27.0  178.00   73.48
# 8                           Anne Dsane Andersen   F  23.0  183.00   86.00
# 9                          Axel Sigurd Andersen   M  20.0  177.22   73.48
# 10                      Camilla Rseler Andersen   F  23.0  169.00   65.00
# 11                      Camilla Rseler Andersen   F  27.0  169.00   65.00
# 12                                Carl Andersen   M  27.0  177.22   73.48
# 13                   Carl Rudolf Svend Andersen   M  20.0  177.22   73.48
# 14                           Carl-Ebbe Andersen   M  19.0  177.22   73.48
# 15             Johan Frederik Kobberup Andersen   M  28.0  177.22   73.48
# 16  Greta Marie Andersen (-Sonnichsen, -Veress)   F  21.0  177.22   73.48
# 17  Greta Marie Andersen (-Sonnichsen, -Veress)   F  21.0  177.22   73.48
# 18        Hjalmart Nrregaard Andersen (-Eering)   M  22.0  177.22   73.48
# 19                       Johan Vilhelm Andersen   M  32.0  177.22   73.48
# 20                            Kristine Andersen   F  28.0  172.00   72.00
# 21                Mads Christian Kruse Andersen   M  30.0  187.00   75.00
# 22                        Peter Marius Andersen   M  23.0  177.22   73.48
# 23                               Niels Andersen   M  44.0  177.22   73.48
# 24                     Peter Villemoes Andersen   M  28.0  177.22   73.48
# 25                 Paul Kuhlman "Poul" Andersen   M  30.0  173.00   73.00
# 26                           Vigo Carl Andersen   M  21.0  177.22   73.48
# 27                        Cyril Romain Andresen   M  26.0  177.22   73.48
# 28                      Eva Johanne Arndt-Riise   F  28.0  177.22   73.48
# 29    Holger Olenius Heinrich Jrgensen Askehave   M  23.0  177.22   73.48
#
#     Year  Season             Sport     Medal  Country
# 0   1900  Summer        Tug-Of-War      Gold  Denmark
# 1   1948  Summer     Equestrianism  No Medal  Denmark
# 2   1952  Summer     Equestrianism  No Medal  Denmark
# 3   1920  Summer        Gymnastics      Gold  Denmark
# 4   1912  Summer            Rowing      Gold  Denmark
# 5   1906  Summer          Football      Gold  Denmark
# 6   1908  Summer         Wrestling    Bronze  Denmark
# 7   1996  Summer          Handball      Gold  Denmark
# 8   2016  Summer            Rowing    Bronze  Denmark
# 9   1912  Summer        Gymnastics    Bronze  Denmark
# 10  1996  Summer          Handball      Gold  Denmark
# 11  2000  Summer          Handball      Gold  Denmark
# 12  1906  Summer        Gymnastics    Silver  Denmark
# 13  1920  Summer        Gymnastics      Gold  Denmark
# 14  1948  Summer            Rowing      Gold  Denmark
# 15  1948  Summer          Canoeing    Silver  Denmark
# 16  1948  Summer          Swimming      Gold  Denmark
# 17  1948  Summer          Swimming    Silver  Denmark
# 18  1912  Summer        Gymnastics    Bronze  Denmark
# 19  1924  Summer  Art Competitions  No Medal  Denmark
# 20  2004  Summer          Handball      Gold  Denmark
# 21  2008  Summer            Rowing      Gold  Denmark
# 22  1908  Summer          Football    Silver  Denmark
# 23  1912  Summer          Shooting    Bronze  Denmark
# 24  1912  Summer        Gymnastics    Silver  Denmark
# 25  1960  Summer          Football    Silver  Denmark
# 26  1906  Summer          Football      Gold  Denmark
# 27  1956  Summer           Sailing    Silver  Denmark
# 28  1948  Summer          Swimming    Silver  Denmark
# 29  1924  Summer         Wrestling  No Medal  Denmark

# %%
df.isnull().sum().where(df.isnull().sum() > 0).dropna()
# Out:
# Series([], dtype: float64)

# %%
df.describe()
# Out:
#                 Age        Height        Weight          Year
# count  45549.000000  45549.000000  45549.000000  45549.000000
# mean      25.855299    177.221788     73.484699   1974.573448
# std        5.902603      9.592879     13.019168     33.335980
# min       10.000000    132.000000     28.000000   1896.000000
# 25%       22.000000    172.000000     66.000000   1952.000000
# 50%       25.000000    177.220000     73.480000   1984.000000
# 75%       28.000000    182.000000     79.000000   2002.000000
# max       73.000000    223.000000    214.000000   2016.000000

# %% [markdown]
# Agora não temos nenhum valor nulo e todos os valores são coerentes. Podemos começar nossa análise.

# %% [markdown]
# ## Análise

# %% [markdown]
# Primeiro começaremos verificando quais são os principais países vencedores e verificando possíveis características que podem agrupar tais atletas

# %%
df.head()
# Out:
#                                Name Sex   Age  Height  Weight  Year  Season  \
# 0              Edgar Lindenau Aabye   M  34.0  177.22   73.48  1900  Summer
# 1                Otto Mnsted Acthon   M  30.0  177.22   73.48  1948  Summer
# 2                Otto Mnsted Acthon   M  34.0  177.22   73.48  1952  Summer
# 3  Georg Albert Christian Albertsen   M  30.0  177.22   73.48  1920  Summer
# 4           Ejler Arild Emil Allert   M  30.0  177.22   73.48  1912  Summer
#
#            Sport     Medal  Country
# 0     Tug-Of-War      Gold  Denmark
# 1  Equestrianism  No Medal  Denmark
# 2  Equestrianism  No Medal  Denmark
# 3     Gymnastics      Gold  Denmark
# 4         Rowing      Gold  Denmark

# %%
top10countries = df[["Country", "Medal"]][df["Medal"] == "Gold"].value_counts().head(10)
# Out:
# Country  Medal
# USA      Gold     2629
# Russia   Gold     1590
# Germany  Gold     1295
# UK       Gold      677
# Italy    Gold      575
# France   Gold      499
# Sweden   Gold      479
# Canada   Gold      460
# Hungary  Gold      430
# Norway   Gold      376
# dtype: int64

# %%
sns.
